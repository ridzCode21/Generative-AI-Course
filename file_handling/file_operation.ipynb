# %% [markdown]
# # File Operation- Read And Write Files
# # File handling is a crucial part of any programming language. Python provides built-in functions and methods to read from and write to files, both text and binary. This lesson will cover the basics of file handling, including reading and writing text files and binary files.

# %%
with open('example.txt','r') as file :
    content = file.read()
    print(content)
# Out:
# cefiefpoev mimcpokcvp vecnicmoevme
# jcnwnciv
# ejvnjnvieev
# jnwnm oe

# %% [markdown]
# #Read a text file and count the number of lines, words, and characters.
# # Counting lines, words, and characters in a text file

# %%
#reading line by line

with open('example.txt','r') as file :
    for line in file :
        print(line.strip())
# Out:
# cefiefpoev mimcpokcvp vecnicmoevme
# jcnwnciv
# ejvnjnvieev
# jnwnm oe

# %%
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            print(line.strip())

# %%
#writer to a file

with open('output.txt','w') as file :
    file.write("This is a new line.\n")
    file.write("Writing to a file using Python.\n")

# append to a file

with open('output.txt','a') as file :
    file.write("Appending a new line.\n")
    file.write("This line is added at the end of the file.\n")
read_file_line_by_line('output.txt')
# Out:
# This is a new line.
# Writing to a file using Python.
# Appending a new line.
# This line is added at the end of the file.

# %%
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

read_file_line_by_line('example.txt')
# Out:
# cefiefpoev mimcpokcvp vecnicmoevme
# jcnwnciv
# ejvnjnvieev
# jnwnm oe
# First line
# Second line
# Third line
# First line
# Second line
# Third line

# %%
def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path = 'example.txt'
lines, words, characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 10, Words: 19, Characters: 137

# %% [markdown]
# # working with file paths

# %%
import os
os.makedirs('folder_name/subfolder_name', exist_ok=True)
file_path = os.path.join('folder_name', 'subfolder_name', 'file.txt')

# %%
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
