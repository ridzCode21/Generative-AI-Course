# %% [markdown]
# # Importing Modules in Python: Modules and Packages
# # In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %% [markdown]
# Standard Library Overview
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import random

list(random.sample(range(1,100),10))
import datetime
now = datetime.datetime.now()
print("Current date and time: ")

# %%
from package.find_single_unique_value import unique

numbers = [1, 2, 2, 3, 4, 4, 5]
print(unique(numbers))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from package.find_single_unique_value import unique
#       3 numbers = [1, 2, 2, 3, 4, 4, 5]
#       4 print(unique(numbers))
#
# ImportError: cannot import name 'unique' from 'package.find_single_unique_value' (/home/riddhesh/genrative_ai_course/Generative-AI-Course/module/package/find_single_unique_value.py)
